# %% [markdown]
# <a href="https://colab.research.google.com/github/AndresVelez31/Parcial-4-Estructura-de-Datos/blob/main/AlgoritmosDeOrdenamiento.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1 align="center">Informe Parcial 4</h1>
# <h1 align="center">Proyecto Final</h1>
# <h1 align="center">Algoritmos de Ordenamiento</h1>
#
#
# ---

# %% [markdown]
# ***Realizado por:***
# - *Andres Felipe Velez Alvarez*
# - *Sara Hurtado Metaute*
# - *Alyson Dahiana Henao Fernandez*

# %% [markdown]
# ## **Link del video**
#
# -

# %% [markdown]
# En este proyecto analizamos ciertos algoritmos de ordenamiento, donde evaluamos la eficiencia de estos. Para realizar una comparación válida nos enfocamos en los dos tipos de algoritmos (directos e indirectos) donde además de analizar el tiempo que se demoran en ordenar listas, ya sean ordenadas, desordenadas, medianamente desordenadas e inversas, realizamos graficas para comparar y analizar su comportamiento.
#
# Los algoritmos utilizados fueron:
# - `Bubble Sort`
# - `Selection Sort`
# - `Insertion Sort`
# - `Shell Sort`
# - `Merge Sort`
# - `Heap Sort`.
#
# Los códigos de los primeros cuatro algoritmos utilizados fueron en base a los pseudocódigos proporcionados en GitHub por el profesor

# %% [markdown]
# # **Algoritmos Directos**

# %% [markdown]
# ### **Bubble Sort:**

# %% [markdown]
#  Compara el elemento inferior de la lista con los restantes y realiza un intercambio de posiciones cuando el orden de comparación no es correcto, básicamente es un ordenamiento por intercambio.
#
# Es un tipo de ordenamiento simple, pero uno de los menos eficientes, pero es fácil de entender y útil para listas pequeñas.

# %%
# Función de bubble sort con contadores de comparaciones e intercambios
def bubble(arreglo):
    n = len(arreglo)
    comparaciones = 0
    intercambios = 0

    for i in range(1, n):
        for j in range(0, n - i):  # Optimización: No revisar las posiciones ya ordenadas
            comparaciones += 1
            if arreglo[j] > arreglo[j + 1]:
                aux = arreglo[j]
                arreglo[j] = arreglo[j + 1]
                arreglo[j + 1] = aux
                intercambios += 1
    return comparaciones, intercambios

# %% [markdown]
# ### **Selection Sort:**

# %% [markdown]
# Selecciona el elemento de menor valor en el arreglo y lo intercambia con el primer elemento del arreglo, realiza el mismo procedimiento con cada uno de los elementos del arreglo considerando las posiciones ya intercambiadas. Al igual que el Bubble no es muy eficiente para listas grandes y no es un algoritmo estable, pero es un algoritmo simple y de poco uso de memoria.
#
# `Selection Sort` fue elegido por su simplicidad y bajo consumo de memoria. Aunque su complejidad es $O(n²)$, lo hace muy lento en comparación con otros algoritmos de ordenamiento eficientes. Se eligió este algoritmo precisamente por su bajo rendimiento en comparación con `Merge Sort`, lo que permite una comparación directa entre un algoritmo muy rápido y uno significativamente más lento. Es ideal para demostrar la diferencia de eficiencia en arreglos pequeños o medianos.

# %%
# Función de selection sort con contadores de comparaciones e intercambios
def selection_sort(arr):
    comparaciones = 0  # Contador de comparaciones
    intercambios = 0   # Contador de intercambios

    # Recorre todo el arreglo
    for i in range(len(arr)):
        act_idx_min = i  # El índice del elemento más pequeño en la parte no ordenada del arreglo

        # Compara el elemento actual con los elementos siguientes
        for j in range(i + 1, len(arr)):
            comparaciones += 1  # Se realiza una comparación
            if arr[j] < arr[act_idx_min]:
                act_idx_min = j  # Si encuentra un elemento menor, actualiza el índice del mínimo

        # Si el índice del mínimo no coincide con el índice actual, intercambia los elementos
        if act_idx_min != i:
            arr[i], arr[act_idx_min] = arr[act_idx_min], arr[i]
            intercambios += 1  # Se realiza un intercambio

    return comparaciones, intercambios  # Devuelve los contadores de comparaciones e intercambios

# %% [markdown]
# ###**Insertion Sort:**

# %% [markdown]
# El primer elemento de la lista se considera ordenado, se inserta el siguiente elemento adelante o detrás el a0 dependiendo si es menor o mayor, utiliza la iteración donde `i = 1` hasta `n-1` buscando la posición correcta (se va moviendo hacia la derecha). Útil para listas de menos de $50$ elementos, puede llegar a ser más rápido que algoritmos más complejos, es un ordenamiento estable y además es útil para datos que llegan de manera secuencial y que necesitan mantener un conjunto ordenado a medida que se añaden datos.

# %%
# Función de insertion sort con contadores de comparaciones e intercambios
def insertion(lista):
    comparaciones = 0  # Contador de comparaciones
    intercambios = 0   # Contador de intercambios

    for i in range(len(lista)):
        actual = lista[i]  # Guarda el valor del elemento actual en una variable temporal
        j = i

        # Mientras el elemento no sea el primero y el elemento anterior sea mayor que este, intercambiar
        while j > 0:
            comparaciones += 1  # Se realiza una comparación
            if lista[j - 1] > actual:
                lista[j] = lista[j - 1]  # Desplaza el elemento anterior una posición adelante
                intercambios += 1  # Se realiza un intercambio
                j -= 1
            else:
                break  # Si no es necesario intercambiar, salir del bucle

        lista[j] = actual  # Una vez encuentra la posición correcta, actualiza el valor

    return comparaciones, intercambios

# %% [markdown]
# ## **Algoritmos Juntos**

# %%
# Función de bubble sort con contadores de comparaciones e intercambios
def bubble(arreglo):
    n = len(arreglo)
    comparaciones = 0
    intercambios = 0

    for i in range(1, n):
        for j in range(0, n - i):  # Optimización: No revisar las posiciones ya ordenadas
            comparaciones += 1
            if arreglo[j] > arreglo[j + 1]:
                aux = arreglo[j]
                arreglo[j] = arreglo[j + 1]
                arreglo[j + 1] = aux
                intercambios += 1
    return comparaciones, intercambios


# Función de selection sort con contadores de comparaciones e intercambios
def selection_sort(arr):
    comparaciones = 0  # Contador de comparaciones
    intercambios = 0   # Contador de intercambios

    # Recorre todo el arreglo
    for i in range(len(arr)):
        act_idx_min = i  # El índice del elemento más pequeño en la parte no ordenada del arreglo

        # Compara el elemento actual con los elementos siguientes
        for j in range(i + 1, len(arr)):
            comparaciones += 1  # Se realiza una comparación
            if arr[j] < arr[act_idx_min]:
                act_idx_min = j  # Si encuentra un elemento menor, actualiza el índice del mínimo

        # Si el índice del mínimo no coincide con el índice actual, intercambia los elementos
        if act_idx_min != i:
            arr[i], arr[act_idx_min] = arr[act_idx_min], arr[i]
            intercambios += 1  # Se realiza un intercambio

    return comparaciones, intercambios  # Devuelve los contadores de comparaciones e intercambios



# Función de insertion sort con contadores de comparaciones e intercambios
def insertion(lista):
    comparaciones = 0  # Contador de comparaciones
    intercambios = 0   # Contador de intercambios

    for i in range(len(lista)):
        actual = lista[i]  # Guarda el valor del elemento actual en una variable temporal
        j = i

        # Mientras el elemento no sea el primero y el elemento anterior sea mayor que este, intercambiar
        while j > 0:
            comparaciones += 1  # Se realiza una comparación
            if lista[j - 1] > actual:
                lista[j] = lista[j - 1]  # Desplaza el elemento anterior una posición adelante
                intercambios += 1  # Se realiza un intercambio
                j -= 1
            else:
                break  # Si no es necesario intercambiar, salir del bucle

        lista[j] = actual  # Una vez encuentra la posición correcta, actualiza el valor

    return comparaciones, intercambios

# %% [markdown]
# # **Algoritmos Indirectos**

# %% [markdown]
# ### **Merge Sort:**

# %% [markdown]
# Consiste en dividir en dos mitades aproximadamente iguales hasta que cada sub-lista contenga máximo un elemento, luego ordena cada uno combinándolas en un arreglo ordenado, compara los elementos y los une en el orden correcto. Va combinando las listas pequeñas en las grandes. A pesar de que tiene un costo adicional en memoria es muy eficiente y tiene buena estabilidad.
#
# Se eligió `Merge Sort` debido a su eficiencia en el peor caso, con una complejidad de $O(n log n)$. Este algoritmo es muy adecuado para conjuntos de datos grandes debido a su rendimiento consistente y predecible. Además, es un algoritmo estable que, aunque utiliza más espacio en memoria debido a la necesidad de almacenamiento adicional para las mitades, es muy eficiente cuando se necesita asegurar un rendimiento de alta calidad. Se seleccionó este algoritmo para comparar su rendimiento frente a uno más lento.

# %%
# Función de merge sort
def merge_sort(arr):
    # Diccionario para almacenar los contadores de comparaciones e intercambios
    contadores = {'comparaciones': 0, 'intercambios': 0}

    def _merge_sort(arr):
        if len(arr) > 1:  # Si el arreglo tiene más de un elemento, lo dividimos
            mitad = len(arr) // 2  # Encuentra el punto medio
            mitad_izquierda = arr[:mitad]  # Parte izquierda del arreglo
            mitad_derecha = arr[mitad:]  # Parte derecha del arreglo

            # Llamadas recursivas para ordenar ambas mitades
            _merge_sort(mitad_izquierda)
            _merge_sort(mitad_derecha)

            # Inicializamos los índices para recorrer las dos mitades
            i = j = k = 0

            # Compara los elementos de las dos mitades y los ordena en el arreglo original
            while i < len(mitad_izquierda) and j < len(mitad_derecha):
                contadores['comparaciones'] += 1

                if mitad_izquierda[i] < mitad_derecha[j]:
                    arr[k] = mitad_izquierda[i]  # Toma el elemento de la mitad izquierda
                    i += 1
                else:
                    arr[k] = mitad_derecha[j]  # Toma el elemento de la mitad derecha
                    j += 1
                k += 1
                contadores['intercambios'] += 1

            # Si quedan elementos en la mitad izquierda, los coloca en el arreglo
            while i < len(mitad_izquierda):
                arr[k] = mitad_izquierda[i]
                i += 1
                k += 1
                contadores['intercambios'] += 1

            # Si quedan elementos en la mitad derecha, los coloca en el arreglo
            while j < len(mitad_derecha):
                arr[k] = mitad_derecha[j]
                j += 1
                k += 1
                contadores['intercambios'] += 1

    # Llamada inicial a la función recursiva
    _merge_sort(arr)
    return contadores['comparaciones'], contadores['intercambios']

# %% [markdown]
# ### **Heap Sort:**

# %% [markdown]
# Utiliza la estructura `heap`, que funciona como un árbol binario completo, donde `max-heap` es el árbol con la propiedad particular de que cada padre es mayor que sus hijos. Luego intercambia el primer valor (`raíz`) con el ultimo elemento del arreglo, reduce el tamaño del `montículo` o `heap` sin tener en cuenta el elemento ya ordenado y restaura el `max-heap` en el subárbol. Este proceso lo repite hasta que todos los elementos estén ordenados. Es un algoritmo eficiente que utiliza poca memoria e independiente del estado inicial de los datos.

# %%
# Función de heap sort con contadores de comparaciones e intercambios
def heap(arr):
    comparaciones = 0  # Contador de comparaciones
    intercambios = 0   # Contador de intercambios

    # Construcción del montículo máximo
    for i in range(len(arr) // 2 - 1, -1, -1):
        comparaciones_locales, intercambios_locales = maxHeap(arr, len(arr), i)
        comparaciones += comparaciones_locales
        intercambios += intercambios_locales

    # Ordenamiento del montículo
    for i in range(len(arr) - 1, 0, -1):
        arr[i], arr[0] = arr[0], arr[i]  # Intercambia el más grande con el último desordenado
        intercambios += 1
        comparaciones_locales, intercambios_locales = maxHeap(arr, i, 0)
        comparaciones += comparaciones_locales
        intercambios += intercambios_locales

    return comparaciones, intercambios


def maxHeap(arr, n, padre):
    masGrande = padre  # Inicializa el mayor como el padre
    izq = (2 * padre) + 1  # Índice del hijo izquierdo
    der = (2 * padre) + 2  # Índice del hijo derecho

    comparaciones = 0  # Contador de comparaciones locales
    intercambios = 0   # Contador de intercambios locales

    # Compara el hijo izquierdo con el padre
    if izq < n:
        comparaciones += 1
        if arr[izq] > arr[masGrande]:
            masGrande = izq

    # Compara el hijo derecho con el mayor actual
    if der < n:
        comparaciones += 1
        if arr[der] > arr[masGrande]:
            masGrande = der

    # Si el mayor no es el padre, intercambia
    if masGrande != padre:
        arr[masGrande], arr[padre] = arr[padre], arr[masGrande]
        intercambios += 1
        # Ajusta el subárbol afectado de forma recursiva
        comparaciones_recursivas, intercambios_recursivos = maxHeap(arr, n, masGrande)
        comparaciones += comparaciones_recursivas
        intercambios += intercambios_recursivos

    return comparaciones, intercambios

# %% [markdown]
# ### **Shell Sort:**

# %% [markdown]
# Utiliza el método de inserción directa donde cada elemento se compara con los elementos contiguos a su izquierda y Shell modifica los saltos contiguos resultantes de las comparaciones por saltos de mayor tamaño, utiliza un salto inicial de $n/2$ que reduce el salto hasta ser tamaño $1$.  Es un algoritmo más eficiente que el de `Insertion Sort` para lista de tamaño mediano, es fácil de implementar, pero recomendados si no se necesita mucho uso de la memoria

# %%
# Función de shell sort con contadores de comparaciones e intercambios
def shell(arr):
    n = len(arr)
    intervalo = n // 2
    comparaciones = 0  # Contador de comparaciones
    intercambios = 0   # Contador de intercambios

    while intervalo > 0:
        for i in range(intervalo, n):
            j = i
            aux = arr[i]

            # Comparar e intercambiar según el intervalo
            while j >= intervalo:
                comparaciones += 1  # Se realiza una comparación
                if arr[j - intervalo] > aux:
                    arr[j] = arr[j - intervalo]
                    j -= intervalo
                    intercambios += 1
                else:
                    break
            arr[j] = aux
        intervalo //= 2

    return comparaciones, intercambios

# %% [markdown]
# ## **Algoritmos Juntos:**

# %%
# Función de merge sort
def merge_sort(arr):
    # Diccionario para almacenar los contadores de comparaciones e intercambios
    contadores = {'comparaciones': 0, 'intercambios': 0}

    def _merge_sort(arr):
        if len(arr) > 1:  # Si el arreglo tiene más de un elemento, lo dividimos
            mitad = len(arr) // 2  # Encuentra el punto medio
            mitad_izquierda = arr[:mitad]  # Parte izquierda del arreglo
            mitad_derecha = arr[mitad:]  # Parte derecha del arreglo

            # Llamadas recursivas para ordenar ambas mitades
            _merge_sort(mitad_izquierda)
            _merge_sort(mitad_derecha)

            # Inicializamos los índices para recorrer las dos mitades
            i = j = k = 0

            # Compara los elementos de las dos mitades y los ordena en el arreglo original
            while i < len(mitad_izquierda) and j < len(mitad_derecha):
                contadores['comparaciones'] += 1

                if mitad_izquierda[i] < mitad_derecha[j]:
                    arr[k] = mitad_izquierda[i]  # Toma el elemento de la mitad izquierda
                    i += 1
                else:
                    arr[k] = mitad_derecha[j]  # Toma el elemento de la mitad derecha
                    j += 1
                k += 1
                contadores['intercambios'] += 1

            # Si quedan elementos en la mitad izquierda, los coloca en el arreglo
            while i < len(mitad_izquierda):
                arr[k] = mitad_izquierda[i]
                i += 1
                k += 1
                contadores['intercambios'] += 1

            # Si quedan elementos en la mitad derecha, los coloca en el arreglo
            while j < len(mitad_derecha):
                arr[k] = mitad_derecha[j]
                j += 1
                k += 1
                contadores['intercambios'] += 1

    # Llamada inicial a la función recursiva
    _merge_sort(arr)
    return contadores['comparaciones'], contadores['intercambios']

# Función de heap sort con contadores de comparaciones e intercambios
def heap(arr):
    comparaciones = 0  # Contador de comparaciones
    intercambios = 0   # Contador de intercambios

    # Construcción del montículo máximo
    for i in range(len(arr) // 2 - 1, -1, -1):
        comparaciones_locales, intercambios_locales = maxHeap(arr, len(arr), i)
        comparaciones += comparaciones_locales
        intercambios += intercambios_locales

    # Ordenamiento del montículo
    for i in range(len(arr) - 1, 0, -1):
        arr[i], arr[0] = arr[0], arr[i]  # Intercambia el más grande con el último desordenado
        intercambios += 1
        comparaciones_locales, intercambios_locales = maxHeap(arr, i, 0)
        comparaciones += comparaciones_locales
        intercambios += intercambios_locales

    return comparaciones, intercambios


def maxHeap(arr, n, padre):
    masGrande = padre  # Inicializa el mayor como el padre
    izq = (2 * padre) + 1  # Índice del hijo izquierdo
    der = (2 * padre) + 2  # Índice del hijo derecho

    comparaciones = 0  # Contador de comparaciones locales
    intercambios = 0   # Contador de intercambios locales

    # Compara el hijo izquierdo con el padre
    if izq < n:
        comparaciones += 1
        if arr[izq] > arr[masGrande]:
            masGrande = izq

    # Compara el hijo derecho con el mayor actual
    if der < n:
        comparaciones += 1
        if arr[der] > arr[masGrande]:
            masGrande = der

    # Si el mayor no es el padre, intercambia
    if masGrande != padre:
        arr[masGrande], arr[padre] = arr[padre], arr[masGrande]
        intercambios += 1
        # Ajusta el subárbol afectado de forma recursiva
        comparaciones_recursivas, intercambios_recursivos = maxHeap(arr, n, masGrande)
        comparaciones += comparaciones_recursivas
        intercambios += intercambios_recursivos

    return comparaciones, intercambios


# Función de shell sort con contadores de comparaciones e intercambios
def shell(arr):
    n = len(arr)
    intervalo = n // 2
    comparaciones = 0  # Contador de comparaciones
    intercambios = 0   # Contador de intercambios

    while intervalo > 0:
        for i in range(intervalo, n):
            j = i
            aux = arr[i]

            # Comparar e intercambiar según el intervalo
            while j >= intervalo:
                comparaciones += 1  # Se realiza una comparación
                if arr[j - intervalo] > aux:
                    arr[j] = arr[j - intervalo]
                    j -= intervalo
                    intercambios += 1
                else:
                    break
            arr[j] = aux
        intervalo //= 2

    return comparaciones, intercambios

# %% [markdown]
# # **Medir Tiempos, Intercambios y Comparaciones**

# %% [markdown]
# A continuacion se mostrara el codigo donde se generan las listas y se miden los tiempos, intercambios y comparaciones que toman los algoritmos ya mencionados anteriormente con $5$ listas de pruebas las cuales van con datos desde $100$ elementos hasta $25.000$ elementos.

# %%
import time
import random
import pandas as pd
from IPython.display import display  # Necesario para mostrar la tabla de manera interactiva en Jupyter

# Función para generar listas de prueba
def generar_lista(tamaño, tipo='aleatorio'):
    if tipo == 'aleatorio':
        return [random.randint(1, 1000) for _ in range(tamaño)]
    elif tipo == 'ordenado':
        return list(range(tamaño))
    elif tipo == 'reverso':
        return list(range(tamaño, 0, -1))
    elif tipo == 'medianamente_ordenada':
        # Lista ordenada parcialmente desordenada
        lista = list(range(tamaño))
        for _ in range(tamaño // 3):  # Desordenamos una fracción de la lista
            i, j = random.sample(range(tamaño), 2)
            lista[i], lista[j] = lista[j], lista[i]
        return lista


# Medición del tiempo de ejecución
def medir_tiempo(func, arr):
    start_time = time.time()
    comparaciones, intercambios = func(arr)
    end_time = time.time()
    tiempo_ejecucion = end_time - start_time
    return tiempo_ejecucion, comparaciones, intercambios


# Tamaños de las listas de prueba
tamaños = [100, 5000, 10000, 15000, 25000]

# Tipos de listas de prueba
tipos_lista = ['aleatorio', 'ordenado', 'reverso', 'medianamente_ordenada']

# Diccionarios para almacenar los tiempos de ejecución
tiempos_merge = {tipo: [] for tipo in tipos_lista}
tiempos_selection = {tipo: [] for tipo in tipos_lista}
tiempos_heap = {tipo: [] for tipo in tipos_lista}
tiempos_shell = {tipo: [] for tipo in tipos_lista}
tiempos_insertion = {tipo: [] for tipo in tipos_lista}
tiempos_bubble = {tipo: [] for tipo in tipos_lista}

# Almacenar las comparaciones de cada algoritmo para cada tipo de lista
comparaciones_merge = {tipo: [] for tipo in tipos_lista}
comparaciones_selection = {tipo: [] for tipo in tipos_lista}
comparaciones_heap = {tipo: [] for tipo in tipos_lista}
comparaciones_shell = {tipo: [] for tipo in tipos_lista}
comparaciones_insertion = {tipo: [] for tipo in tipos_lista}
comparaciones_bubble = {tipo: [] for tipo in tipos_lista}

# Almacenar los intercambios de cada algoritmo para cada tipo de lista
intercambios_merge = {tipo: [] for tipo in tipos_lista}
intercambios_selection = {tipo: [] for tipo in tipos_lista}
intercambios_heap = {tipo: [] for tipo in tipos_lista}
intercambios_shell = {tipo: [] for tipo in tipos_lista}
intercambios_insertion = {tipo: [] for tipo in tipos_lista}
intercambios_bubble = {tipo: [] for tipo in tipos_lista}

# Diccionario para almacenar los resultados por tipo de lista
resultados = {tipo: [] for tipo in tipos_lista}

# Medir los tiempos para cada algoritmo y tipo de lista
for tipo in tipos_lista:
    for tamaño in tamaños:
        lista = generar_lista(tamaño, tipo)

        # Merge Sort
        tiempo_merge, comparaciones_merge_val, intercambios_merge_val = medir_tiempo(merge_sort, lista.copy())
        tiempos_merge[tipo].append(tiempo_merge)
        comparaciones_merge[tipo].append(comparaciones_merge_val)
        intercambios_merge[tipo].append(intercambios_merge_val)
        resultados[tipo].append([tamaño, "Merge Sort", tiempo_merge, comparaciones_merge_val, intercambios_merge_val])

        # Selection Sort
        tiempo_selection, comparaciones_selection_val, intercambios_selection_val = medir_tiempo(selection_sort, lista.copy())
        tiempos_selection[tipo].append(tiempo_selection)
        comparaciones_selection[tipo].append(comparaciones_selection_val)
        intercambios_selection[tipo].append(intercambios_selection_val)
        resultados[tipo].append([tamaño, "Selection Sort", tiempo_selection, comparaciones_selection_val, intercambios_selection_val])

        # Heap Sort
        tiempo_heap, comparaciones_heap_val, intercambios_heap_val = medir_tiempo(heap, lista.copy())
        tiempos_heap[tipo].append(tiempo_heap)
        comparaciones_heap[tipo].append(comparaciones_heap_val)
        intercambios_heap[tipo].append(intercambios_heap_val)
        resultados[tipo].append([tamaño, "Heap Sort", tiempo_heap, comparaciones_heap_val, intercambios_heap_val])

        # Shell Sort
        tiempo_shell, comparaciones_shell_val, intercambios_shell_val = medir_tiempo(shell, lista.copy())
        tiempos_shell[tipo].append(tiempo_shell)
        comparaciones_shell[tipo].append(comparaciones_shell_val)
        intercambios_shell[tipo].append(intercambios_shell_val)
        resultados[tipo].append([tamaño, "Shell Sort", tiempo_shell, comparaciones_shell_val, intercambios_shell_val])

        # Insertion Sort
        tiempo_insertion, comparaciones_insertion_val, intercambios_insertion_val = medir_tiempo(insertion, lista.copy())
        tiempos_insertion[tipo].append(tiempo_insertion)
        comparaciones_insertion[tipo].append(comparaciones_insertion_val)
        intercambios_insertion[tipo].append(intercambios_insertion_val)
        resultados[tipo].append([tamaño, "Insertion Sort", tiempo_insertion, comparaciones_insertion_val, intercambios_insertion_val])

        # Bubble Sort
        tiempo_bubble, comparaciones_bubble_val, intercambios_bubble_val = medir_tiempo(bubble, lista.copy())
        tiempos_bubble[tipo].append(tiempo_bubble)
        comparaciones_bubble[tipo].append(comparaciones_bubble_val)
        intercambios_bubble[tipo].append(intercambios_bubble_val)
        resultados[tipo].append([tamaño, "Bubble Sort", tiempo_bubble, comparaciones_bubble_val, intercambios_bubble_val])

# Función para mostrar los resultados en formato de tabla
def mostrar_tabla(resultados):
    # Creamos un DataFrame de pandas con los resultados
    df = pd.DataFrame(resultados, columns=["Tamaño", "Algoritmo", "Tiempo (s)", "Comparaciones", "Intercambios"])
    display(df)  # Usamos display para mostrar la tabla interactiva

# Mostrar las tablas para cada tipo de lista
for tipo in tipos_lista:
    print(f"\n--- Resultados con Lista {tipo.capitalize()} ---")
    mostrar_tabla(resultados[tipo])
# Out:
# --- Resultados con Lista Aleatorio ---
#     Tamaño       Algoritmo  Tiempo (s)  Comparaciones  Intercambios
# 0      100      Merge Sort    0.000393            545           672
# 1      100  Selection Sort    0.000580           4950            94
# 2      100       Heap Sort    0.000438           1027           578
# 3      100      Shell Sort    0.000214            909           454
# 4      100  Insertion Sort    0.000593           2432          2339
# 5      100     Bubble Sort    0.001035           4950          2339
# 6     5000      Merge Sort    0.033022          55209         61808
# 7     5000  Selection Sort    1.891769       12497500          4988
# 8     5000       Heap Sort    0.080591         107681         57086
# 9     5000      Shell Sort    0.058059         108371         55898
# 10    5000  Insertion Sort    3.036437        6170165       6165174
# 11    5000     Bubble Sort    3.226429       12497500       6165174
# 12   10000      Merge Sort    0.068909         120440        133616
# 13   10000  Selection Sort    6.412364       49995000          9979
# 14   10000       Heap Sort    0.175721         235270        124003
# 15   10000      Shell Sort    0.125804         238102        123187
# 16   10000  Insertion Sort    9.161278       25013940      25003950
# 17   10000     Bubble Sort   14.530617       49995000      25003950
# 18   15000      Merge Sort    0.105551         189303        208616
# 19   15000  Selection Sort   16.205827      112492500         14974
# 20   15000       Heap Sort    0.285760         370178        194732
# 21   15000      Shell Sort    0.203868         387501        215187
# 22   15000  Insertion Sort   19.235466       55594496      55579501
# 23   15000     Bubble Sort   31.450657      112492500      55579501
# 24   25000      Merge Sort    0.189520         334047        367232
# 25   25000  Selection Sort   45.528364      312487500         24969
# 26   25000       Heap Sort    0.283049         654773        343596
# 27   25000      Shell Sort    0.207828         727482        415290
# 28   25000  Insertion Sort   52.303934      155013710     154988718
# 29   25000     Bubble Sort   91.930928      312487500     154988718
# --- Resultados con Lista Ordenado ---
#     Tamaño       Algoritmo  Tiempo (s)  Comparaciones  Intercambios
# 0      100      Merge Sort    0.000333            316           672
# 1      100  Selection Sort    0.000554           4950             0
# 2      100       Heap Sort    0.000458           1081           640
# 3      100      Shell Sort    0.000098            503             0
# 4      100  Insertion Sort    0.000021             99             0
# 5      100     Bubble Sort    0.000641           4950             0
# 6     5000      Merge Sort    0.028072          29804         61808
# 7     5000  Selection Sort    1.511932       12497500             0
# 8     5000       Heap Sort    0.052915         112126         60932
# 9     5000      Shell Sort    0.016717          55005             0
# 10    5000  Insertion Sort    0.001066           4999             0
# 11    5000     Bubble Sort    1.851540       12497500             0
# 12   10000      Merge Sort    0.055157          64608        133616
# 13   10000  Selection Sort    6.057655       49995000             0
# 14   10000       Heap Sort    0.100534         244460        131956
# 15   10000      Shell Sort    0.048187         120005             0
# 16   10000  Insertion Sort    0.003882           9999             0
# 17   10000     Bubble Sort    8.894270       49995000             0
# 18   15000      Merge Sort    0.086537         102252        208616
# 19   15000  Selection Sort   15.271473      112492500             0
# 20   15000       Heap Sort    0.156112         383177        205644
# 21   15000      Shell Sort    0.038792         180007             0
# 22   15000  Insertion Sort    0.003158          14999             0
# 23   15000     Bubble Sort   20.330076      112492500             0
# 24   25000      Merge Sort    0.150538         178756        367232
# 25   25000  Selection Sort   43.458084      312487500             0
# 26   25000       Heap Sort    0.275489         677688        361454
# 27   25000      Shell Sort    0.071233         325006             0
# 28   25000  Insertion Sort    0.005279          24999             0
# 29   25000     Bubble Sort   54.140685      312487500             0
# --- Resultados con Lista Reverso ---
#     Tamaño       Algoritmo  Tiempo (s)  Comparaciones  Intercambios
# 0      100      Merge Sort    0.000339            356           672
# 1      100  Selection Sort    0.000586           4950            50
# 2      100       Heap Sort    0.000378            944           516
# 3      100      Shell Sort    0.000151            668           260
# 4      100  Insertion Sort    0.001215           4950          4950
# 5      100     Bubble Sort    0.001534           4950          4950
# 6     5000      Merge Sort    0.026905          32004         61808
# 7     5000  Selection Sort    1.578674       12497500          2500
# 8     5000       Heap Sort    0.039561         103227         53436
# 9     5000      Shell Sort    0.019442          78798         28780
# 10    5000  Insertion Sort    5.000453       12497500      12497500
# 11    5000     Bubble Sort    4.224170       12497500      12497500
# 12   10000      Merge Sort    0.055884          69008        133616
# 13   10000  Selection Sort    7.773709       49995000          5000
# 14   10000       Heap Sort    0.180697         226682        116696
# 15   10000      Shell Sort    0.055240         172578         62560
# 16   10000  Insertion Sort   16.096749       49995000      49995000
# 17   10000     Bubble Sort   19.277606       49995000      49995000
# 18   15000      Merge Sort    0.088732         106364        208616
# 19   15000  Selection Sort   17.038862      112492500          7500
# 20   15000       Heap Sort    0.275302         357789        184182
# 21   15000      Shell Sort    0.138181         261020         95996
# 22   15000  Insertion Sort   35.522034      112492500     112492500
# 23   15000     Bubble Sort   45.273766      112492500     112492500
# 24   25000      Merge Sort    0.156326         188476        367232
# 25   25000  Selection Sort   44.830093      312487500         12500
# 26   25000       Heap Sort    0.257564         633719        326586
# 27   25000      Shell Sort    0.130391         486165        186140
# 28   25000  Insertion Sort  105.497073      312487500     312487500
# 29   25000     Bubble Sort  125.270654      312487500     312487500
# --- Resultados con Lista Medianamente_ordenada ---
#     Tamaño       Algoritmo  Tiempo (s)  Comparaciones  Intercambios
# 0      100      Merge Sort    0.000712            510           672
# 1      100  Selection Sort    0.001225           4950            33
# 2      100       Heap Sort    0.000899           1059           615
# 3      100      Shell Sort    0.000382            852           375
# 4      100  Insertion Sort    0.000750           1504          1405
# 5      100     Bubble Sort    0.001573           4950          1405
# 6     5000      Merge Sort    0.060128          54239         61808
# 7     5000  Selection Sort    1.991657       12497500          1666
# 8     5000       Heap Sort    0.043891         109589         58794
# 9     5000      Shell Sort    0.026974         107187         53638
# 10    5000  Insertion Sort    0.994869        3534967       3529970
# 11    5000     Bubble Sort    2.538054       12497500       3529970
# 12   10000      Merge Sort    0.069914         118444        133616
# 13   10000  Selection Sort    7.117598       49995000          3331
# 14   10000       Heap Sort    0.182038         239341        127643
# 15   10000      Shell Sort    0.128521         258692        141607
# 16   10000  Insertion Sort    4.638703       14449554      14439557
# 17   10000     Bubble Sort   12.304842       49995000      14439557
# 18   15000      Merge Sort    0.107499         186403        208616
# 19   15000  Selection Sort   15.458794      112492500          4998
# 20   15000       Heap Sort    0.154907         375941        199978
# 21   15000      Shell Sort    0.118423         392032        216492
# 22   15000  Insertion Sort   11.267346       32380645      32365646
# 23   15000     Bubble Sort   27.124388      112492500      32365646
# 24   25000      Merge Sort    0.189165         329194        367232
# 25   25000  Selection Sort   43.786332      312487500          8333
# 26   25000       Heap Sort    0.281236         665298        352639
# 27   25000      Shell Sort    0.235087         772289        454759
# 28   25000  Insertion Sort   31.015960       89572504      89547507
# 29   25000     Bubble Sort   74.362151      312487500      89547507
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %% [markdown]
# # **Graficas de Tiempo**

# %% [markdown]
# A continuacion se mostrara el codigo donde se crean y se ejecutan las graficas de tiempo utilizando la libreria de `python` llamada `matplotlib` en base a los datos que hemos recolectado anteriormente.

# %%
import matplotlib.pyplot as plt

# Graficar tiempos de ejecución
def graficar_tiempos(tiempos_merge, tiempos_selection, tiempos_heap, tiempos_shell, tiempos_insertion, tiempos_bubble, tamaños, tipo_lista, ax):
    ax.plot(tamaños, tiempos_merge, label=f"Merge Sort ({tipo_lista})", color='blue', marker='o', linestyle='-')
    ax.plot(tamaños, tiempos_selection, label=f"Selection Sort ({tipo_lista})", color='red', marker='o', linestyle='--')
    ax.plot(tamaños, tiempos_heap, label=f"Heap Sort ({tipo_lista})", color='green', marker='o', linestyle='-.')
    ax.plot(tamaños, tiempos_shell, label=f"Shell Sort ({tipo_lista})", color='purple', marker='o', linestyle=':')
    ax.plot(tamaños, tiempos_insertion, label=f"Insertion Sort ({tipo_lista})", color='orange', marker='o', linestyle='-.')
    ax.plot(tamaños, tiempos_bubble, label=f"Bubble Sort ({tipo_lista})", color='brown', marker='o', linestyle='-')

    ax.set_title(f"Tiempo de Ejecución de Ordenación ({tipo_lista.capitalize()})", fontsize=12)
    ax.set_xlabel("Tamaño de Entrada", fontsize=10)
    ax.set_ylabel("Tiempo (segundos)", fontsize=10)
    ax.grid(True, linestyle='--', alpha=0.7)
    ax.legend(fontsize=8)

    # Escala logarítmica solo en el eje Y
    ax.set_yscale('log')

# Graficar resultados
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

# Graficar los tiempos para cada tipo de lista
for i, tipo in enumerate(tipos_lista):
    ax = axs[i // 2, i % 2]
    graficar_tiempos(tiempos_merge[tipo], tiempos_selection[tipo], tiempos_heap[tipo], tiempos_shell[tipo], tiempos_insertion[tipo], tiempos_bubble[tipo], tamaños, tipo, ax)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Graficas de Comparaciones**

# %% [markdown]
# A continuacion se mostrara el codigo donde se crean y se ejecutan las graficas de comparaciones utilizando la libreria de `python` llamada `matplotlib` en base a los datos que hemos recolectado anteriormente.

# %%
# Graficar comparaciones
def graficar_comparaciones(comparaciones_merge, comparaciones_selection, comparaciones_heap, comparaciones_shell, comparaciones_insertion, comparaciones_bubble, tamaños, tipo_lista, ax):
    ax.plot(tamaños, comparaciones_merge, label=f"Merge Sort ({tipo_lista})", color='blue', marker='o', linestyle='-')
    ax.plot(tamaños, comparaciones_selection, label=f"Selection Sort ({tipo_lista})", color='red', marker='o', linestyle='--')
    ax.plot(tamaños, comparaciones_heap, label=f"Heap Sort ({tipo_lista})", color='green', marker='o', linestyle='-.')
    ax.plot(tamaños, comparaciones_shell, label=f"Shell Sort ({tipo_lista})", color='purple', marker='o', linestyle=':')
    ax.plot(tamaños, comparaciones_insertion, label=f"Insertion Sort ({tipo_lista})", color='orange', marker='o', linestyle='-.')
    ax.plot(tamaños, comparaciones_bubble, label=f"Bubble Sort ({tipo_lista})", color='brown', marker='o', linestyle='-')

    ax.set_title(f"Comparaciones de Ordenación ({tipo_lista.capitalize()})", fontsize=12)
    ax.set_xlabel("Tamaño de Entrada", fontsize=10)
    ax.set_ylabel("Número de Comparaciones", fontsize=10)
    ax.grid(True, linestyle='--', alpha=0.7)
    ax.legend(fontsize=8)

    # Escala logarítmica solo en el eje Y
    ax.set_yscale('log')

# Graficar las comparaciones de cada tipo de lista
fig, axs = plt.subplots(2, 2, figsize=(14, 10))

# Graficar las comparaciones para cada tipo de lista
for i, tipo in enumerate(tipos_lista):
    ax = axs[i // 2, i % 2]
    graficar_comparaciones(comparaciones_merge[tipo], comparaciones_selection[tipo], comparaciones_heap[tipo], comparaciones_shell[tipo], comparaciones_insertion[tipo], comparaciones_bubble[tipo], tamaños, tipo, ax)

plt.tight_layout()
plt.show()

# %% [markdown]
# # **Metodologia**

# %% [markdown]
# ## **Herramientas utilizadas:**

# %% [markdown]
# El proyecto fue realizado en `Python` y utilizamos la herramienta `Google Colab`, nos ayudamos de librerías propias del lenguaje como `time` para determinar los tiempos utilizados por cada algoritmo, `random` para generar listas de datos aleatorios, `matplotlib.pyplot` para generar las gráficas y `pandas` y `IPython.display` para la tabla comparativa.

# %% [markdown]
# ## **Implementación de algoritmos:**

# %% [markdown]
# El objetivo de implementar los algoritmos de ordenamiento es comparar su rendimiento tanto en términos de tiempo como de comparaciones realizadas en función de la cantidad de datos ingresados. Los algoritmos utilizados fueron escogidos estratégicamente para comparar el rendimiento tanto de los directos como de los indirectos, seleccionando 3 de cada uno.

# %% [markdown]
# ## **Paso a paso:**

# %% [markdown]
# El paso a paso a seguir fue primero crear los códigos de los algoritmos de ordenamiento que, como se mencionó anteriormente, cuatro de ellos fueron hechos de acuerdo con los pseudocódigos y los últimos dos nos apoyamos en videos para su correcta ejecución. Luego de esto para realizar las gráficas dado que no teníamos conocimiento de como realizarlas en código utilizamos ayuda de la IA y así aprender cómo se realizaban estas.

# %% [markdown]
# ## **Recopilación de datos:**

# %% [markdown]
# Gracias a la utilización de las herramientas como las librerías `random` y `time` almacenamos en diccionarios datos como el tiempo de ejecución, comparaciones de los algoritmos y los intervalos de cada uno de los resultados para posteriormente ser utilizados en la realización de las diferentes gráficas y además la creación de una tabla que nos muestra los diferentes algoritmos y sus respectivos tiempos, comparaciones, intercambios y tamaño.

# %% [markdown]
# # **Resultados**

# %% [markdown]
# ## **Resultados Numericos:**

# %% [markdown]
# Estos son mostrados en tablas donde cada una representan las pruebas que realizamos que fueron a base de: una lista `aleatoria`, `ordenada`, `medianamente ordenadas` e `inversas`. Cada vez que se corre el programa no siempre va a ser la misma lista dado a la utilización la la librería `random`. Utilizamos cinco tipos de tamaños `[100,5000,10000,15000,25000]` y como se mencionó anteriormente esta nos muestra el tiempo en que se demoró en ejecutar el ordenamiento, las comparaciones e intercambios realizados por cada uno de los 6 tipos de algoritmos que utilizamos. El resultado en este caso fue:

# %% [markdown]
# <div style="display: flex; justify-content: center; margin-bottom: 20px;">
#   <img src="https://raw.githubusercontent.com/AndresVelez31/Parcial-4-Estructura-de-Datos/refs/heads/main/Images/Tabla1.png" width="45%" style="margin-right: 10px;" />
#   <img src="https://raw.githubusercontent.com/AndresVelez31/Parcial-4-Estructura-de-Datos/refs/heads/main/Images/Tabla2.png" width="45%" />
# </div>
#
# <div style="display: flex; justify-content: center;">
#   <img src="https://raw.githubusercontent.com/AndresVelez31/Parcial-4-Estructura-de-Datos/refs/heads/main/Images/Tabla3.png" width="45%" style="margin-right: 10px;" />
#   <img src="https://raw.githubusercontent.com/AndresVelez31/Parcial-4-Estructura-de-Datos/refs/heads/main/Images/Tabla4.png" width="45%" />
# </div>

# %% [markdown]
# ## **Graficas**

# %% [markdown]
# Se realizaron dos tipos de grafica (tiempo de ejecución y comparaciones de ordenamiento) las cuales cada uno nos muestran las cuatro pruebas realizadas con las listas ya previamente mencionadas.

# %% [markdown]
# <div style="text-align: center; margin-bottom: 10px;">
#   <h2><strong>Gráfica 1: Analisis de Tiempos</strong></h2>
# </div>
# <div style="display: flex; justify-content: center; align-items: center; margin-bottom: 20px;">
#   <img src="https://raw.githubusercontent.com/AndresVelez31/Parcial-4-Estructura-de-Datos/refs/heads/main/Images/Grafica1.png"
#        style="max-width: 100%; height: auto;" alt="Gráfica 1"/>
# </div>
#
# ---
#
# <div style="text-align: center; margin-bottom: 10px;">
#   <h2><strong>Gráfica 2: Análisis de Comparaciones</strong></h2>
# </div>
# <div style="display: flex; justify-content: center; align-items: center;">
#   <img src="https://raw.githubusercontent.com/AndresVelez31/Parcial-4-Estructura-de-Datos/refs/heads/main/Images/Grafica2.png"
#        style="max-width: 100%; height: auto;" alt="Gráfica 2"/>
# </div>

# %% [markdown]
# ## **Analisis de Resultados**

# %% [markdown]
# ###**Rendimiento Temporal**

# %% [markdown]
# Los algoritmos presentan diferencias significativas en tiempos de ejecución dependiendo del tamaño y el estado inicial de la lista:
#
# **Tamaños pequeños**: Todos los algoritmos tienen tiempos similares, ya que la cantidad de datos es pequeña, y las diferencias en complejidad no se reflejan significativamente.
#
# **Tamaños grandes**:
#
# - Algoritmos avanzados como *`Merge Sort`* y *`Heap Sort`* tienen tiempos bajos gracias a su complejidad $O(n log n)$, incluso con listas grandes y desordenadas.
# - Algoritmos simples como *`Bubble Sort`* e *`Insertion Sort`* muestran tiempos mucho mayores debido a su complejidad $O(n^2)$.

# %% [markdown]
# ###**Rendimiento Espacial:**

# %% [markdown]
# - *`Merge Sort`* requiere memoria adicional para las sublistas que genera, lo que lo hace menos eficiente espacialmente en comparación con otros algoritmos.
# - *`Heap Sort`* y *`Shell Sort`* tienen un mejor manejo del espacio porque trabajan sobre el arreglo original sin requerir almacenamiento extra significativo.

# %% [markdown]
# ###**Tendencias con el tamaño de listas:**

# %% [markdown]
# **Algoritmos Avanzados (Merge Sort, Heap Sort, Shell Sort):**
#
# - El tiempo de ejecución crece de manera más lenta con el tamaño de la lista, gracias a su complejidad $O(nlogn)$
# - Son consistentes en listas grandes, independientemente del estado inicial.
#
# **Algoritmos Simples (Bubble Sort, Selection Sort, Insertion Sort):**
# - El tiempo crece de manera cuadrática $O(n^2)$, lo que los hace inadecuados para tamaños grandes.
# - Funcionan mejor en listas pequeñas o ya ordenadas.

# %% [markdown]
# # **Conclusiones**

# %% [markdown]
# Tras comparar los resultados obtenidos, se pueden destacar las siguientes conclusiones:
#
# **1. Rendimiento en Tamaños Pequeños:**
#
# - Para tamaños pequeños, los algoritmos tienen tiempos de ejecución muy similares debido a la poca cantidad de datos. Por ejemplo, el tiempo más lento fue $0,001573$ segundos y el más rápido $0,000021$ segundos.
# - Las diferencias en eficiencia son menos notorias en este rango, ya que el número de operaciones es reducido, minimizando el impacto de la complejidad algorítmica.
#
# **2. Rendimiento en Tamaños Grandes:**
#
# - A medida que el tamaño de la lista aumenta, los algoritmos avanzados como `Merge Sort` y `Heap Sort` demuestran una ventaja considerable en tiempo y número de comparaciones. Por ejemplo, alcanzaron $0,28$ segundos y $667,688$ comparaciones en listas grandes.
# - En contraste, algoritmos simples como `Bubble Sort` e `Insertion Sort` son los menos eficientes, especialmente en listas grandes y desordenadas, mostrando tiempos extremadamente altos (hasta $125,27$ segundos) y una cantidad masiva de comparaciones e intercambios ($312,487,500$ operaciones).
#
# **3. Eficiencia de Algoritmos Avanzados:**
#
# - Algoritmos como `Merge Sort`, `Heap Sort` y `Shell Sort` destacan por su eficiencia, incluso en listas grandes y completamente desordenadas, gracias a su complejidad más favorable $O(nlogn)$.
#
# **4. Impacto del Estado Inicial:**
#
# - En listas **ya ordenadas o casi ordenadas**, algoritmos simples como `Bubble Sort` e `Insertion Sort` mejoran significativamente su rendimiento, ya que minimizan el número de intercambios.
# - Algoritmos como `Merge Sort` mantienen un rendimiento constante sin importar el estado inicial, ya que siempre procesan la lista de manera similar.
# - En listas **inversamente ordenadas**, los algoritmos simples sufren considerablemente, realizando el máximo número de operaciones y mostrando los peores tiempos.
#
# **5. Ventajas de los Algoritmos Avanzados:**
# - Son la mejor opción para manejar listas grandes o desordenadas, donde la eficiencia es crucial.
# - Aunque algunos, como `Merge Sort`, requieren más memoria, su rendimiento temporal compensa esta desventaja en la mayoría de los casos.
#
# **6. Limitaciones de los Algoritmos Simples:**
# - Su uso está restringido a listas pequeñas o ya ordenadas debido a su alta complejidad temporal
# $O(n^2)$.
# - Sin embargo, su simplicidad y baja exigencia de memoria los hace útiles en escenarios específicos o como soluciones rápidas en situaciones controladas.

# %% [markdown]
# # **Referencias**

# %% [markdown]
# https://www.w3schools.com/python/matplotlib_subplot.asp
#
# https://www.youtube.com/watch?v=wB9C0Mz9gSo
#
# https://www.datacamp.com/tutorial/matplotlib-tutorial-python
#
# https://www.geeksforgeeks.org/merge-sort/
#
# https://www.w3schools.com/dsa/dsa_algo_mergesort.php
#
# https://www.youtube.com/watch?v=ACFZn_xQcz8&t=1s&pp=ygUKbWVyZ2Ugc29ydA%3D%3D
#
# https://www.youtube.com/watch?v=cVZMah9kEjI&t=2s&pp=ygUKbWVyZ2Ugc29ydA%3D%3D
#
# https://www.programiz.com/dsa/merge-sort
#
# https://www.geeksforgeeks.org/selection-sort-algorithm-2/
#
# https://www.w3schools.com/dsa/dsa_algo_selectionsort.php
#
# https://www.programiz.com/dsa/selection-sort
#
# https://www.youtube.com/watch?v=g-PGLbMth_g&pp=ygUOc2VsZWN0aW9uIHNvcnQ%3D
#
# https://www.youtube.com/watch?v=ee80YmiaSVQ&pp=ygUOc2VsZWN0aW9uIHNvcnQ%3D
